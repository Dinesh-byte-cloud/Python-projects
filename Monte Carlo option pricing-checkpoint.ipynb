# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt
from scipy.stats import norm
# %matplotlib inline

# %%
ticker = 'PG'
data = pd.DataFrame()
data[ticker] = wb.DataReader(ticker, data_source='yahoo',start='2007-1-1',end ='2022-3-21')['Adj Close']

# %%
log_returns = np.log(1 + data.pct_change())

# %%
r = 0.025

# %%
stdev = log_returns.std() * 250 **0.5

# %%
stdev = stdev.values
stdev
# Out:
# array([0.18590045])

# %%
T = 1.0
t_intervals = 250
delta_t = T/t_intervals

iterations = 10000

# %%
Z = np.random.standard_normal((t_intervals + 1, iterations))
S = np.zeros_like(Z)
S0 = data.iloc[-1]
S[0] = S0

# %%
for t in range(1,t_intervals + 1):
    S[t] = S[t-1] * np.exp((r - 0.5 * stdev ** 2) * delta_t + stdev * delta_t ** 0.5 * Z[t])

# %%
S
# Out:
# array([[147.86303711, 147.86303711, 147.86303711, ..., 147.86303711,
#         147.86303711, 147.86303711],
#        [148.62136943, 146.87347398, 146.43594858, ..., 147.69865864,
#         147.27099285, 147.11237817],
#        [145.16413132, 148.53423484, 149.93643929, ..., 147.26942628,
#         146.46719856, 147.06562513],
#        ...,
#        [160.21093836, 166.73075509, 143.19615256, ..., 150.25697839,
#         116.9382757 , 156.37190291],
#        [155.98961171, 170.30265073, 140.10053039, ..., 149.65570647,
#         116.83447788, 156.84556855],
#        [154.03211051, 168.28659652, 140.0156985 , ..., 152.52193103,
#         118.28296286, 159.9595541 ]])

# %%
S.shape
# Out:
# (251, 10000)

# %%
plt.figure(figsize=(10,6))
plt.plot(S[:, :10])
# Out:
# [<matplotlib.lines.Line2D at 0x1af73d0eaf0>,
#  <matplotlib.lines.Line2D at 0x1af73d0ebb0>,
#  <matplotlib.lines.Line2D at 0x1af73d0ec70>,
#  <matplotlib.lines.Line2D at 0x1af73d0ed30>,
#  <matplotlib.lines.Line2D at 0x1af73d0edf0>,
#  <matplotlib.lines.Line2D at 0x1af73d0eeb0>,
#  <matplotlib.lines.Line2D at 0x1af73d0ef70>,
#  <matplotlib.lines.Line2D at 0x1af76f85070>,
#  <matplotlib.lines.Line2D at 0x1af76f85130>,
#  <matplotlib.lines.Line2D at 0x1af76f851f0>]

# %%
p = np.maximum(S[-1] -110,0)

# %%
p
# Out:
# array([44.03211051, 58.28659652, 30.0156985 , ..., 42.52193103,
#         8.28296286, 49.9595541 ])

# %%
p.shape
# Out:
# (10000,)

# %%
C = np.exp(-r * T) * np.sum(p)  / iterations
C
# Out:
# 40.78678437874272
